# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# %matplotlib inline


img =mpimg.imread("iphonex.png")
imgplot = plt.imshow(img)

# %%
import scipy 
from scipy import ndimage
plt.figure(figsize=(12,2))

for degree in range(5):
    plt.subplot(151+degree)
    rotate_imge = scipy.ndimage.rotate(img, degree*60)
    plt.imshow(rotate_imge, cmap=plt.cm.gray)
    plt.axis("off")
    
plt.show()

# %%
from PIL import Image
import numpy as np
from numpy import array
import scipy
from scipy import ndimage

#img = Image.open("iphonex.png")
#arr = np.array(img)
a = scipy.ndimage.imread('iphonex.jpg', mode='RGB')
print("a=",a)

img = Image.fromarray(arr)
#img.save("output.png")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-57496b69b58a> in <module>()
#       7 #img = Image.open("iphonex.png")
#       8 #arr = np.array(img)
# ----> 9 a = scipy.ndimage.imread('iphonex.jpg', mode='RGB')
#      10 print("a=",a)
#      11
#
# /usr/local/lib/python3.5/site-packages/scipy/ndimage/io.py in imread(fname, flatten, mode)
#      23     if _have_pil:
#      24         return _imread(fname, flatten, mode)
# ---> 25     raise ImportError("Could not import the Python Imaging Library (PIL)"
#      26                       " required to load image files.  Please refer to"
#      27                       " http://pillow.readthedocs.org/en/latest/installation.html"
#
# ...

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt


im=Image.open("iphonex.png")
arr=np.array(im)
for i in range(arr.shape[1]):
    arr[:,i]=np.roll(arr[:,i],3)
    
plt.axis("off")
plt.imshow(arr)
plt.show()
